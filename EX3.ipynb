# %% [markdown]
# <a href="https://colab.research.google.com/github/rithikakulal12/rithika1234/blob/main/EX3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
max=lambda a,b:a if(a>b)else b
print(max(4,5))
x=lambda a:a+1
print(x(5))
x=lambda a,b,c:a+b+c
print(x(5,6,2))
# Out:
# 5
# 6
# 13

# %%
def add4(x):
    return x+4
list1=[4,5,6,7,8,9]
list2=list(map(add4,list1))
print(list2)
# Out:
# [8, 9, 10, 11, 12, 13]

# %%
def start_with_A(S):
  return S[0]=="A"
fruit=["Apple","banana","pear","apricot","orange"]
map_object=map(start_with_A,fruit)
print(list(map_object))
# Out:
# [True, False, False, False, False]

# %%
def start_with_A(S):
  return S[0]=="A"
fruit=["Apple","banana","pear","Apricot","orange"]
filter_object=filter(start_with_A,fruit)
print(list(filter_object))
# Out:
# ['Apple', 'Apricot']

# %%
def oddeven(x):
  if x%2==0:
    return True
  else:
    return False
list1=[4,5,6,7,8,9]
evenlist=list(filter(oddeven,list1))
print(evenlist)
# Out:
# [4, 6, 8]

# %%
from functools import reduce
def sum(x,y):
 return x+y
list1=[6,7,8,9]
s=reduce(sum,list1)
print(s)
# Out:
# 30
