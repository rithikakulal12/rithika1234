# %% [markdown]
# <a href="https://colab.research.google.com/github/rithikakulal12/rithika1234/blob/main/EX2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'first':['aryan','rohan','riya','yash','siddini'],
    'lastname':['singh','agarwal','shah','batia','khan'],
    'type':['full_time employee','intern','full_time employee','part time employee','full_time employee'],
    'department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,0],
    }
df=pd.DataFrame(data)
print(df)
# Out:
#      first lastname                type      department  yoe  salary
# 0    aryan    singh  full_time employee  administration    2   20000
# 1    rohan  agarwal              intern       technical    3    5000
# 2     riya     shah  full_time employee  administration    5   10000
# 3     yash    batia  part time employee       technical    7   20000
# 4  siddini     khan  full_time employee       technical    6       0
